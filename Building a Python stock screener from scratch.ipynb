# %%
import pandas as pd
import yahoo_fin.stock_info as yf
from datetime import datetime as dt
from pandas_datareader import data
import pandas_datareader as pdr

# %%
#get tickers
tickers= yf.tickers_sp500() #manual input is an option

# %%
capitalization=0
cash=0
investment=0
debt=0
ev=0
net_income=0

# %%
def market_cap(ticker):
    global caplitalization
    share_row=0
    stats=yf.get_stats(ticker)
    price=float(yf.get_live_price(ticker))
    
    #dicover row
    for i in range(len(stats["Attribute"])):
        if (stats["Attribute"][i]=="Shares Outstanding 5"):
            break
        else:
            share_row+=1
     
    shares=stats["Value"][share_row]
    
    #Adjust for letter m
    if shares[-1].lower()=="m":
        shares=float(shares[:-1])
    elif shares[-1].lower()=="b":
        shares=float(shares[:-1])*1000
    
    #calculate market cap
    capitalization=shares*price
    return capitalization

# %%
def bs(ticker):
    global capitalization
    global cash
    global investment
    global debt
    global ev
    
    stats=yf.get_stats(ticker)
    balance_sheet=yf.get_balance_sheet(ticker,yearly=False)
    years=balance_sheet.columns
    investments=0
    count_debts=0
    count_cash=0
    
    #find row for  debt
    for i in range(len(stats["Attribute"])):
        if stats["Attribute"][i]=="Total Debt (mrq)":
            break
        else:
            count_debts+=1
        
        debt=stats["Value"][count_debts]
        
    # Adjust for letter
    if debt[-1].lower()=='m':
        debt=float(debt[:-1])
    elif debt[-1].lower()=="b":
        debt=float(debt[:-1])*1000
    
    #find row for cash
    for i in range (len(stats["Attribute"])):
        if stats["Attribute"][i]=="Total Cash (mrq)":
            break
        else:
            count_cash+=1
        
        cash=stats["Value"][count_cash]
        
    # Adjust for letter
    if cash[-1].lower()=='m':
        cash=float(cash[:-1])
    elif cash[-1].lower()=="b":
        cash=float(cash[:-1])*1000

    #Investments
    try:
        investmetns=balance_sheet[year[0]]["longTermInvestments"]/1000000
    except:
        investment=0
            
        ev=capitalization-cash-investment+ debt

# %%
def income_statement(ticker):
    global net_inc
    quarterly_is= yf.get_income_statement(ticker, yearly=False)
    years=quarterly_is.columns
    
    for i in range(4):
        net_inc+= quarterly_is[year[i]]["netIncomeFromContinuingOps"]

# %%
summary = pd.DataFrame(columns = ['Ticker', 'Market cap','Net income',
                                  'Cash', 'Debt', 'Investments', 'Enterprise value'])

# %%
def collect_data():
    global summary
    for ticker in tickers:
        try:
            market_cap(ticker)
            bs(ticker)
            income_statement(ticker)
            new_row={"Ticker": ticker,"Market Cap": capitalization, "cash": cash,"Investment":investment, "Enterprise Value":ev,
                    "Net Income": net_inc}
            
            summary=summary.append(new_row, ignore_index=True)
        except:
            print(ticker+" Something went wrong")
    
    summary.to_csv("summary.csv")

# %%
collect_data()
# Out:
# A Something went wrong
# AAL Something went wrong
# AAP Something went wrong
# AAPL Something went wrong
# ABBV Something went wrong
# ABC Something went wrong
# ABMD Something went wrong
# ABT Something went wrong
# ACGL Something went wrong
# ACN Something went wrong
# ADBE Something went wrong
# ADI Something went wrong
# ADM Something went wrong
# ADP Something went wrong
# ADSK Something went wrong
# AEE Something went wrong
# AEP Something went wrong
# AES Something went wrong
# AFL Something went wrong
# AIG Something went wrong
# AIZ Something went wrong
# AJG Something went wrong
# AKAM Something went wrong
# ALB Something went wrong
# ALGN Something went wrong
# ALK Something went wrong
# ALL Something went wrong
# ALLE Something went wrong
# AMAT Something went wrong
# AMCR Something went wrong
# AMD Something went wrong
# AME Something went wrong
# AMGN Something went wrong
# AMP Something went wrong
# AMT Something went wrong
# AMZN Something went wrong
# ANET Something went wrong
# ANSS Something went wrong
# AON Something went wrong
# AOS Something went wrong
# APA Something went wrong
# APD Something went wrong
# APH Something went wrong
# APTV Something went wrong
# ARE Something went wrong
# ATO Something went wrong
# ATVI Something went wrong
# AVB Something went wrong
# AVGO Something went wrong
# AVY Something went wrong
# AWK Something went wrong
# AXP Something went wrong
# AZO Something went wrong
# BA Something went wrong
# BAC Something went wrong
# BALL Something went wrong
# BAX Something went wrong
# BBWI Something went wrong
# BBY Something went wrong
# BDX Something went wrong
# BEN Something went wrong
# BF-B Something went wrong
# BIIB Something went wrong
# BIO Something went wrong
# BK Something went wrong
# BKNG Something went wrong
# BKR Something went wrong
# BLK Something went wrong
# BMY Something went wrong
# BR Something went wrong
# BRK-B Something went wrong
# BRO Something went wrong
# BSX Something went wrong
# BWA Something went wrong
# BXP Something went wrong
# C Something went wrong
# CAG Something went wrong
# CAH Something went wrong
# CARR Something went wrong
# CAT Something went wrong
# CB Something went wrong
# CBOE Something went wrong
# CBRE Something went wrong
# CCI Something went wrong
# CCL Something went wrong
# CDAY Something went wrong
# CDNS Something went wrong
# CDW Something went wrong
# CE Something went wrong
# CEG Something went wrong
# CF Something went wrong
# CFG Something went wrong
# CHD Something went wrong
# CHRW Something went wrong
# CHTR Something went wrong
# CI Something went wrong
# CINF Something went wrong
# CL Something went wrong
# CLX Something went wrong
# CMA Something went wrong
# CMCSA Something went wrong
# CME Something went wrong
# CMG Something went wrong
# CMI Something went wrong
# CMS Something went wrong
# CNC Something went wrong
# CNP Something went wrong
# COF Something went wrong
# COO Something went wrong
# COP Something went wrong
# COST Something went wrong
# CPB Something went wrong
# CPRT Something went wrong
# CPT Something went wrong
# CRL Something went wrong
# CRM Something went wrong
# CSCO Something went wrong
# CSGP Something went wrong
# CSX Something went wrong
# CTAS Something went wrong
# CTLT Something went wrong
# CTRA Something went wrong
# CTSH Something went wrong
# CTVA Something went wrong
# CVS Something went wrong
# CVX Something went wrong
# CZR Something went wrong
# D Something went wrong
# DAL Something went wrong
# DD Something went wrong
# DE Something went wrong
# DFS Something went wrong
import yahoo_fin.stock_info as yf
import pandas as pd

'''
Two ways to create a screener:
1. Create a filter while gathering the data.
2. Collect data & filter based on multiple criteria afterwards.
'''

#Get tickers
tickers = yf.tickers_sp500() #manual input is an option

#
capitalization = 0
cash = 0
investments = 0
debt = 0
ev = 0
net_inc = 0

#Output in a dataframe
summary = pd.DataFrame(columns = ['Ticker', 'Market cap','Net income',
                                  'Cash', 'Debt', 'Investments', 'Enterprise value'])

def market_cap(ticker):
    global capitalization
    shares_row = 0
    stats = yf.get_stats(ticker)
    price = float(yf.get_live_price(ticker))

    #Discover the row
    for i in range(len(stats['Attribute'])):
        if stats['Attribute'][i] == 'Shares Outstanding 5':
            break
        else:
            shares_row += 1
    
    shares = stats['Value'][shares_row]
    #Adjust for the letter
    if shares[-1].lower() == 'm':
        shares = float(shares[:-1])
    elif shares[-1].lower() == 'b':
        shares = float(shares[:-1])*1000

    #Calculate market cap in millions         
    capitalization = shares * price

def bs(ticker):
    global capitalization
    global cash
    global investments
    global debt
    global ev
    stats = yf.get_stats(ticker)
    balance_sheet = yf.get_balance_sheet(ticker, yearly=False)
    years = balance_sheet.columns
    investments = 0    
    count_debt = 0
    count_cash = 0
    
    #Find the row for debt
    for i in range(len(stats['Attribute'])):
        if stats['Attribute'][i] == 'Total Debt (mrq)':
            break
        else:
            count_debt += 1

    debt = stats['Value'][count_debt]

    #Adjust for the letter
    if debt[-1].lower() == 'm':
        debt = float(debt[:-1])
    elif debt[-1].lower() == 'b':
        debt = float(debt[:-1])*1000   
    
    #Find the row for cash
    for i in range(len(stats['Attribute'])):
        if stats['Attribute'][i] == 'Total Cash (mrq)':
            break
        else:
            count_cash += 1
            
    cash = stats['Value'][count_cash]
    
    #Adjust for the letter
    if cash[-1].lower() == 'm':
        cash = float(cash[:-1])
    elif cash[-1].lower() == 'b':
        cash = float(cash[:-1])*1000

    #Investments
    try:
        investments = balance_sheet[years[0]]['longTermInvestments']/1000000
    except:
        investments = 0

    ev = capitalization - cash - investments + debt
    
def income_statement(ticker):
    global net_inc
    net_inc = 0
    quarterly_is = yf.get_income_statement(ticker, yearly = False)
    years = quarterly_is.columns
    for i in range(4):
        net_inc += quarterly_is[years[i]]['netIncomeFromContinuingOps']        
    
def cfs(ticker):
    pass

def collect_data():
    global summary
    for ticker in tickers[0:5]:
        try:
            market_cap(ticker)
            bs(ticker)
            income_statement(ticker)
            cfs(ticker)
            new_row = {'Ticker': ticker,
                       'Market cap': capitalization,                       
                       'Cash': cash,
                       'Debt': debt,
                       'Investments': investments,
                       'Enterprise value': ev,
                       'Net income': net_inc,}

            summary = summary.append(new_row, ignore_index = True)
            print(ticker + ' added.')
        except:
            print(ticker + ': Something went wrong.')
    summary.to_csv('summary.csv')
                
collect_data()
